# %% [markdown]
# # Layer Experiment Similarity Signals
#
# Analyze sweep similarity curves around a reference layer.

# %%
EXPERIMENT = "layer_exp"
RUN_ID = None  # e.g. "last_layers_run_001"; None selects the newest run directory
METRICS_TO_PLOT = ["softmax_rwka", "rbf_rwka", "cka_rbf", "mutual_knn", "cknna"]
REF_LAYER = 10
SAMPLE_PARAM = 1.0

# %%
import pathlib
import sys

start = pathlib.Path.cwd().resolve()
for candidate in [start, *start.parents]:
    if (candidate / "paths.py").exists():
        REPO_DIR = candidate
        break
else:
    raise RuntimeError("Could not find repo root containing paths.py")

if str(REPO_DIR) not in sys.path:
    sys.path.insert(0, str(REPO_DIR))

from paths import resources_path
from experiments.sweep_analysis import (
    add_experiment_preset_columns,
    entries_to_dataframe,
    list_sweep_metrics,
    load_sweep_entries,
    sample_similarity_at_param,
    save_preset_plots,
)

def latest_run(results_root):
    runs = [path for path in results_root.iterdir() if path.is_dir()]
    if not runs:
        raise FileNotFoundError(f"No run directories found under {results_root}")
    return max(runs, key=lambda path: path.stat().st_mtime)

results_root = resources_path / "results" / EXPERIMENT
results_path = results_root / RUN_ID if RUN_ID else latest_run(results_root)
sweeps_dir = results_path / "sweeps"
figures_dir = results_path / "figures" / "sweep_signals"
figures_dir.mkdir(parents=True, exist_ok=True)

print(f"Results path: {results_path}")
print(f"Sweeps path: {sweeps_dir}")
print(f"Figures path: {figures_dir}")
# Out:
# Results path: /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001
# Sweeps path: /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/sweeps
# Figures path: /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals

# %%
available_metrics = list_sweep_metrics(sweeps_dir)
metrics = [metric for metric in METRICS_TO_PLOT if metric in available_metrics]
if not metrics:
    metrics = available_metrics
print(f"Available sweep metrics: {available_metrics}")
print(f"Plotting metrics: {metrics}")

entries = load_sweep_entries(sweeps_dir)
sweep_df = entries_to_dataframe(entries)
sweep_df = add_experiment_preset_columns(sweep_df, EXPERIMENT, ref_layer=REF_LAYER)
print(sweep_df.shape)
print(sorted(sweep_df.columns))
sweep_df.head()
# Out:
# Available sweep metrics: ['cka_rbf', 'cknna', 'mutual_knn', 'rbf_rwka', 'softmax_rwka']
# Plotting metrics: ['softmax_rwka', 'rbf_rwka', 'cka_rbf', 'mutual_knn', 'cknna']
# (36302, 36)
# ['CKA', 'PWCCA', 'Procrustes', 'architecture1', 'architecture2', 'cka_rbf', 'cka_rbf_auc', 'cknna', 'cknna_auc', 'dataset1', 'dataset2', 'layer1', 'layer2', 'layer_gap', 'mean_cca_corr', 'mean_sq_cca_corr', 'metric', 'metric_auc', 'mutual_knn', 'mutual_knn_auc', 'other_layer', 'param_name', 'param_values', 'path', 'rbf_rwka', 'rbf_rwka_auc', 'same_seed', 'scores', 'seed1', 'seed2', 'seed_mode', 'softmax_rwka', 'softmax_rwka_auc', 'step1', 'step2', 'uses_ref_layer']
#                                                 path   metric   metric_auc  \
# 0  /Users/barweiss/Code/grounded-repsim/sim_metri...  cka_rbf  cka_rbf_auc
# 1  /Users/barweiss/Code/grounded-repsim/sim_metri...  cka_rbf  cka_rbf_auc
# 2  /Users/barweiss/Code/grounded-repsim/sim_metri...  cka_rbf  cka_rbf_auc
# 3  /Users/barweiss/Code/grounded-repsim/sim_metri...  cka_rbf  cka_rbf_auc
# 4  /Users/barweiss/Code/grounded-repsim/sim_metri...  cka_rbf  cka_rbf_auc
#
#   param_name                                       param_values  \
# 0  rbf_sigma  [0.01, 0.012389903709420908, 0.015350971392872...
# 1  rbf_sigma  [0.01, 0.012389903709420908, 0.015350971392872...
# 2  rbf_sigma  [0.01, 0.012389903709420908, 0.015350971392872...
# 3  rbf_sigma  [0.01, 0.012389903709420908, 0.015350971392872...
# 4  rbf_sigma  [0.01, 0.012389903709420908, 0.015350971392872...
#
#                                               scores          dataset1  \
# 0  [0.9999999999998695, 0.9999999999998695, 0.999...  mnli_matched_100
# 1  [0.9999999999998747, 0.999999999999871, 0.9999...  mnli_matched_100
# 2  [0.9999999999998749, 0.9999999999998729, 0.999...  mnli_matched_100
# 3  [0.9999999999998771, 0.9999999999998709, 0.999...  mnli_matched_100
# 4  [0.9999999999998748, 0.9999999999998734, 0.999...  mnli_matched_100
#
#   architecture1  seed1    step1  ...  cknna_auc softmax_rwka softmax_rwka_auc  \
# 0          base     10  2000000  ...        NaN          NaN              NaN
# 1          base     10  2000000  ...        NaN          NaN              NaN
# 2          base     10  2000000  ...        NaN          NaN              NaN
# 3          base     10  2000000  ...        NaN          NaN              NaN
# 4          base     10  2000000  ...        NaN          NaN              NaN
#
#    rbf_rwka  rbf_rwka_auc  same_seed  seed_mode  other_layer  uses_ref_layer  \
# 0       NaN           NaN       True  same_seed          NaN           False
# 1       NaN           NaN       True  same_seed          NaN           False
# 2       NaN           NaN       True  same_seed          0.0            True
# 3       NaN           NaN       True  same_seed          NaN           False
# 4       NaN           NaN       True  same_seed          NaN           False
#
#    layer_gap
# 0          0
# 1          1
# 2         10
# 3         11
# 4          2
#
# [5 rows x 36 columns]

# %%
saved_paths = save_preset_plots(
    sweep_df,
    experiment=EXPERIMENT,
    metrics=metrics,
    figures_dir=figures_dir,
    ref_layer=REF_LAYER,
)
saved_paths
# Out:
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_softmax_rwka_ref_layer_same_seed.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_softmax_rwka_ref_layer_different_seed.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_softmax_rwka_ref_layer_all.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_rbf_rwka_ref_layer_same_seed.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_rbf_rwka_ref_layer_different_seed.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_rbf_rwka_ref_layer_all.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_cka_rbf_ref_layer_same_seed.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_cka_rbf_ref_layer_different_seed.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_cka_rbf_ref_layer_all.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_mutual_knn_ref_layer_same_seed.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_mutual_knn_ref_layer_different_seed.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_mutual_knn_ref_layer_all.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_cknna_ref_layer_same_seed.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_cknna_ref_layer_different_seed.png
# Saved figure to /Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_cknna_ref_layer_all.png
# [PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_softmax_rwka_ref_layer_same_seed.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_softmax_rwka_ref_layer_different_seed.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_softmax_rwka_ref_layer_all.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_rbf_rwka_ref_layer_same_seed.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_rbf_rwka_ref_layer_different_seed.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_rbf_rwka_ref_layer_all.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_cka_rbf_ref_layer_same_seed.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_cka_rbf_ref_layer_different_seed.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_cka_rbf_ref_layer_all.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_mutual_knn_ref_layer_same_seed.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_mutual_knn_ref_layer_different_seed.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_mutual_knn_ref_layer_all.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_cknna_ref_layer_same_seed.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_cknna_ref_layer_different_seed.png'),
#  PosixPath('/Users/barweiss/Code/grounded-repsim/sim_metric_resources/results/layer_exp/last_layers_run_001/figures/sweep_signals/layer_exp_cknna_ref_layer_all.png')]

# %%
# Future heatmap scaffold: merge this sampled dataframe with full_df_self_computed.csv
# on representation metadata columns, then correlate similarity_at_param with task diffs.
sampled_df = sample_similarity_at_param(sweep_df, SAMPLE_PARAM, metric_name=metrics[0] if metrics else None)
sampled_df[["metric", "sampled_param", "similarity_at_param", "seed1", "seed2", "layer1", "layer2"]].head()
# Out:
#              metric  sampled_param  similarity_at_param  seed1  seed2  layer1  \
# 29042  softmax_rwka            1.0             1.000000     10     10       0
# 29043  softmax_rwka            1.0             0.997475     10     10       0
# 29044  softmax_rwka            1.0             0.961894     10     10       0
# 29045  softmax_rwka            1.0             0.958153     10     10       0
# 29046  softmax_rwka            1.0             0.993214     10     10       0
#
#        layer2
# 29042       0
# 29043       1
# 29044      10
# 29045      11
# 29046       2
